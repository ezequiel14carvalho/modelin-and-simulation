# %%
import numpy as np

# Parâmetros
a0 = 2.0
v0 = 10
t1 = v0/a0
t2 = 3*t1
t3 = t1 + t2

def vel(T):
    v_t = np.zeros(T+1)

    for t in range(0, T+1):
        if t < t1:
            v_t[t] = a0*t
        elif t < t2:
            v_t[t] = v0
        elif t < t3:
            v_t[t] = v0 - a0*(t-t2)

    return v_t

def pos(T):
    x_t = np.zeros(T+1)

    for t in range(0, T+1):
        if t < t1:
            x_t[t] = 1/2*a0*t**2
        elif t < t2:
# Out:
# [ 0.  2.  4.  6.  8. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10. 10.  8.  6.
#   4.  2.  0.]
